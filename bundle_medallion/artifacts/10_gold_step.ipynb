# %% [markdown]
# # Medallion demo -- gold 10
# Idempotent demo pipeline step.

# %%
from pyspark.sql import functions as F
spark.sql("CREATE SCHEMA IF NOT EXISTS demo_gold")
df = spark.table("demo_silver.step_10_clean")
metric = df.agg(F.lit(10).alias("metric_step"), F.count("*").alias("record_count"), F.sum("amount").alias("total_amount"), F.avg("amount").alias("average_amount"))
metric.write.mode("overwrite").format("delta").saveAsTable("demo_gold.step_10_metrics")
metric.show()
print("gold step 10 complete")
