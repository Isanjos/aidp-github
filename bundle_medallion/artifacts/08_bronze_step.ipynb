# %% [markdown]
# # Medallion demo -- bronze 08
# Idempotent demo pipeline step.

# %%
from pyspark.sql import functions as F
spark.sql("CREATE SCHEMA IF NOT EXISTS demo_bronze")
rows = [(801, "item_8_a", 80.0), (802, "item_8_b", 160.0)]
df = spark.createDataFrame(rows, ["record_id", "item", "amount"])
df = df.withColumn("source_step", F.lit(8)).withColumn("ingested_at", F.current_timestamp())
df.write.mode("overwrite").format("delta").saveAsTable("demo_bronze.step_08_raw")
print("bronze step 08 complete")
