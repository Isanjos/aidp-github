# %% [markdown]
# # Medallion demo -- gold 06
# Idempotent demo pipeline step.

# %%
from pyspark.sql import functions as F
spark.sql("CREATE SCHEMA IF NOT EXISTS demo_gold")
df = spark.table("demo_silver.step_06_clean")
metric = df.agg(F.lit(6).alias("metric_step"), F.count("*").alias("record_count"), F.sum("amount").alias("total_amount"), F.avg("amount").alias("average_amount"))
metric.write.mode("overwrite").format("delta").saveAsTable("demo_gold.step_06_metrics")
metric.show()
print("gold step 06 complete")
