# %% [markdown]
# # Medallion demo -- bronze 09
# Idempotent demo pipeline step.

# %%
from pyspark.sql import functions as F
spark.sql("CREATE SCHEMA IF NOT EXISTS demo_bronze")
rows = [(901, "item_9_a", 90.0), (902, "item_9_b", 180.0)]
df = spark.createDataFrame(rows, ["record_id", "item", "amount"])
df = df.withColumn("source_step", F.lit(9)).withColumn("ingested_at", F.current_timestamp())
df.write.mode("overwrite").format("delta").saveAsTable("demo_bronze.step_09_raw")
print("bronze step 09 complete")
